# %%
using Plots

# %%
H = [1 1 3 5 5 1; 1 4 6 4 1 1]
# Out:
# 2×6 Array{Int64,2}:
#  1  1  3  5  5  1
#  1  4  6  4  1  1

# %%
plot([(1,1), (1,4), (3,6), (5,4), (5,1), (1,1)])

# %%
plot!([x for x in zip(H[1,:], H[2,:])])

# %%
new_H = [0 1; 1 0]*H
plot([x for x in zip(H[1,:], H[2,:])])
plot!([x for x in zip(new_H[1,:], new_H[2,:])])

# %%
function make_grow(x)
    H = [1 1 3 5 5 1; 1 4 6 4 1 1]
    new_H = [1 0; 0 1]*H
    for i in range(1,5)
         return plot!([x for x in zip(new_H[1,:], new_H[2,:])])
        I = [1+i 0; 0 1+i]
    end
end
# Out:
# make_grow (generic function with 1 method)

# %%
make_grow(4)
